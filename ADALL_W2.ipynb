# %% [markdown]
# <a href="https://colab.research.google.com/github/glenncyop/ADALL/blob/main/ADALL_W2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
from openai import OpenAI
import pandas as pd

# Load key from Google Colab Secrets
api_key = userdata.get('OPENAI_API_KEY')

client = OpenAI(
    # This is the default and can be omitted
    api_key=api_key,
)

# Load dataset
data = 'https://raw.githubusercontent.com/glenncyop/ADALL/main/laptop_prices_2024_sgd_TL.csv'
df = pd.read_csv(data)
print("Data Loaded")

# Convert the first few rows to a string to send to OpenAI
data_preview = df.head(10).to_csv(index=False)
print(data_preview)

response = client.responses.create(
    model="gpt-4o-mini",
    instructions="You are an expert data scientist with extensive knowledge of predictive analysis and linear regression.",
    input=f"Dataset: Iris flower classification (150 samples, 4 features, 3 classes)\nHere are the first 10 rows of the dataset:\n{data_preview}",
)
print(response.output_text)
# Out:
# Data Loaded
# Brand,Model,CPU,GPU,RAM_GB,Storage_Type,Storage_GB,Touchscreen,Weight_kg,Screen_Size_inch,Discount_percent,Price_SGD,Brand_Discount,Member_Discount
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4070,64,SSD,256,False,1.56,16.0,3.27,2413.36,5,144.8
# Acer,Nitro 5,AMD Ryzen 9 8900HX,AMD Radeon 780M,32,SSD,1024,True,1.45,14.0,5.03,1773.75,5,124.16
# Acer,Nitro 5,AMD Ryzen 5 8600H,NVIDIA RTX 4050,32,SSD,2048,False,1.34,14.0,4.41,1634.07,5,98.04
# Acer,TravelMate P6,Intel Core Ultra 7 15500H,NVIDIA RTX 4060,16,SSD,4096,True,1.18,13.3,2.16,2362.59,5,118.13
# Acer,Predator Helios 300,Intel i7-14800H,NVIDIA RTX 4070,8,SSD,1024,True,1.31,14.0,6.93,2218.55,5,155.3
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4080,32,SSD,256,False,3.34,17.3,8.94,2224.12,5,155.69
# Acer,TravelMate P6,Intel i9-14900HK,NVIDIA RTX 4080,128,SSD,1024,True,1.11,13.3,11.72,3016.36,5,211.15
# Acer,Predator Helios 300,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,True,1.29,13.3,8.84,2579.29,5,180.55
# Acer,Swift 3,Intel i5-14500H,NVIDIA RTX 4050,64,SSD,4096,False,1.4,13.3,6.92,1976.94,5,98.85
# Acer,Nitro 5,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,False,1.15,13.3,5.25,2538.34,5,152.3
#
# It looks like you've provided a dataset related to laptop specifications, rather than the Iris flower classification dataset. This dataset contains various features such as CPU, GPU, RAM, storage, and pricing attributes for different laptop models.
#
# ### Key Features of the Dataset:
# - **Brand**: Laptop brand (e.g., Acer)
# - **Model**: Specific model of the laptop
# - **CPU**: Specification of the processor
# - **GPU**: Graphics processing unit information
# - **RAM_GB**: Amount of RAM in gigabytes
# - **Storage_Type**: Type of storage (e.g., SSD)
# - **Storage_GB**: Storage capacity in gigabytes
# - **Touchscreen**: Whether the laptop has a touchscreen (True/False)
# - **Weight_kg**: Weight in kilograms
# - **Screen_Size_inch**: Screen size in inches
# - **Discount_percent**: Discount percentage applied
# - **Price_SGD**: Price in Singapore dollars
# - **Brand_Discount**: Discount offered by the brand
# - **Member_Discount**: Discount for members
#
# ### Potential Analysis
# Here are some predictive analysis tasks you could perform with this dataset:
#
# 1. **Price Prediction**: Use features like CPU, GPU, RAM, and storage to predict the price of the laptop. Linear regression would be appropriate for this type of analysis.
#
# 2. **Feature Importance**: Determine which features most significantly impact the price using techniques like Lasso regression or random forests for feature importance.
#
# 3. **Clustering Analysis**: Group laptops based on similarities in features to help identify market segments.
#
# 4. **Regression Model Evaluation**: Assess the performance of various regression models (e.g., linear regression, polynomial regression) through metrics such as R-squared, MAE, or RMSE.
#
# ### Steps for Price Prediction Using Linear Regression
# 1. **Data Preprocessing**:
#    - Handle categorical variables (e.g., Brand, Model, CPU, GPU) using one-hot encoding or label encoding.
#    - Normalize or standardize numerical features (e.g., RAM, Weight, Screen Size).
#
# 2. **Train-Test Split**: Divide the dataset into training and testing sets to evaluate model performance.
#
# 3. **Model Training**:
#    - Choose a linear regression model (simple or multiple regression depending on features).
#    - Train the model on the training set.
#
# 4. **Model Evaluation**:
#    - Use the testing set to predict prices and calculate evaluation metrics.
#    - Visualize predictions vs. actual prices using scatter plots.
#
# 5. **Hyperparameter Tuning**: Optionally, optimize model parameters using techniques like cross-validation.
#
# If you want to dive deeper into a specific analysis, or if you have questions about a certain aspect of the dataset, let me know!
